# %%
import pandas as pd
import numpy as np
import time
# !pip install googletrans==4.0.0-rc1
# !pip install --upgrade anuvaad
# !pip install -U easynmt
# !pip install google-transliteration-api
# !pip install indic-transliteration

# %%
from googletrans import Translator
translator = Translator()
(translator.translate("This is 23 test sentence.", dest='hi')).text

# %%
from anuvaad import Anuvaad
anu = Anuvaad("english-hindi")
anu.anuvaad("This is 23 test sentence.")

# %%
from easynmt import EasyNMT
model = EasyNMT('m2m_100_418M')
model.translate("Single SIM (Micro-SIM) or Dual SIM (Micro-SIM, dual stand-by)", target_lang='hi')

# %%
from google.transliteration import transliterate_numerals
transliterate_numerals("यह 23 टेस्ट वाक्य है।", lang_code='hi')

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

transliterate('GSM / HSPA / LTE', sanscript.IAST, sanscript.DEVANAGARI)

# %%
#phones = pd.read_csv('../input/GSM/2.GSMtrans.csv', na_filter = False)
phones = pd.read_csv('2.GSM trans.csv', na_filter = False)
phones
# Out:
#      maker_name maker_name_trans           device_name     device_name_trans  \
# 0          Acer            अचेर्     Chromebook Tab 10    छ्रोमेबोओक् तब् १०
# 1          Acer            अचेर्         Iconia Talk S       इचोनिअ तल्क् स्
# 2          Acer            अचेर्        Liquid Z6 Plus    लिक़ुइद् ज़्६ प्लुस्
# 3          Acer            अचेर्             Liquid Z6           लिक़ुइद् ज़्६
# 4          Acer            अचेर्  Iconia Tab 10 A3-A40  इचोनिअ तब् १० अ३-अ४०
# ...         ...              ...                   ...                   ...
# 9531        ZTE             ज़्ते                  F600                 फ़्६००
# 9532        ZTE             ज़्ते                  F103                 फ़्१०३
# 9533        ZTE             ज़्ते                  F101                 फ़्१०१
# 9534        ZTE             ज़्ते                  F100                 फ़्१००
# 9535        ZTE             ज़्ते       Coral200 Sollar      चोरल्२०० सोल्लर्
#
#                                     article_description  \
# 0     Acer Chromebook Tab 10 tablet. Announced Mar 2...
# 1     Acer Iconia Talk S Android tablet. Announced A...
# 2     Acer Liquid Z6 Plus Android smartphone. Announ...
# 3     Acer Liquid Z6 Android smartphone. Announced A...
# 4     Acer Iconia Tab 10 A3-A40 Android tablet. Anno...
# ...                                                 ...
# 9531  ZTE F600 phone. Announced  2009. Features 2.4″...
# 9532  ZTE F103 phone. Announced  2009. Features 2.0″...
# 9533  ZTE F101 phone. Announced  2009. Features 2.0″...
# 9534  ZTE F100 phone. Announced  2009. Features 2.0″...
# 9535  ZTE Coral200 Sollar phone. Announced May 2007....
#
#                               article_description_trans  \
# 0     अचेर् छ्रोमेबोओक् तब् १० तब्लेत्। अन्नोउन्चेद्...
# 1     अचेर् इचोनिअ तल्क् स् अन्द्रोइद् तब्लेत्। अन्न...
# 2     अचेर् लिक़ुइद् ज़्६ प्लुस् अन्द्रोइद् स्मर्त्फोन...
# 3     अचेर् लिक़ुइद् ज़्६ अन्द्रोइद् स्मर्त्फोने। अन्न...
# 4     अचेर् इचोनिअ तब् १० अ३-अ४० अन्द्रोइद् तब्लेत्।...
# ...                                                 ...
# 9531  ज़्ते फ़्६०० फोने। अन्नोउन्चेद्  २००९। फ़ेअतुरेस्...
# 9532  ज़्ते फ़्१०३ फोने। अन्नोउन्चेद्  २००९। फ़ेअतुरेस्...
# 9533  ज़्ते फ़्१०१ फोने। अन्नोउन्चेद्  २००९। फ़ेअतुरेस्...
# 9534  ज़्ते फ़्१०० फोने। अन्नोउन्चेद्  २००९। फ़ेअतुरेस्...
# 9535  ज़्ते चोरल्२०० सोल्लर् फोने। अन्नोउन्चेद् मय् २...
#
#                                         device_img_link  \
# 0     https://cdn2.gsmarena.com/vv/bigpic/acer-chrom...
# 1     https://cdn2.gsmarena.com/vv/bigpic/acer-iconi...
# 2     https://cdn2.gsmarena.com/vv/bigpic/acer-liqui...
# 3     https://cdn2.gsmarena.com/vv/bigpic/acer-liqui...
# 4     https://cdn2.gsmarena.com/vv/bigpic/acer-iconi...
# ...                                                 ...
# 9531   https://cdn2.gsmarena.com/vv/bigpic/zte-f600.jpg
# 9532   https://cdn2.gsmarena.com/vv/bigpic/zte-f103.jpg
# 9533   https://cdn2.gsmarena.com/vv/bigpic/zte-f101.jpg
# 9534   https://cdn2.gsmarena.com/vv/bigpic/zte-f100.jpg
# 9535  https://cdn2.gsmarena.com/vv/bigpic/zte-coral2...
#
#                                          reference_link  \
# 0     https://www.gsmarena.com/acer_chromebook_tab_1...
# 1     https://www.gsmarena.com/acer_iconia_talk_s-83...
# 2     https://www.gsmarena.com/acer_liquid_z6_plus-8...
# 3      https://www.gsmarena.com/acer_liquid_z6-8304.php
# 4     https://www.gsmarena.com/acer_iconia_tab_10_a3...
# ...                                                 ...
# 9531         https://www.gsmarena.com/zte_f600-3102.php
# 9532         https://www.gsmarena.com/zte_f103-3099.php
# 9533         https://www.gsmarena.com/zte_f101-3101.php
# 9534         https://www.gsmarena.com/zte_f100-3100.php
# 9535  https://www.gsmarena.com/zte_coral200_sollar-3...
#
#             network_technology     network_technology_trans  ...  \
# 0     No cellular connectivity  कोई सेलुलर कनेक्टिविटी नहीं  ...
# 1             GSM / HSPA / LTE         जीएसएम/एचएसपीए/एलटीई  ...
# 2             GSM / HSPA / LTE         जीएसएम/एचएसपीए/एलटीई  ...
# 3             GSM / HSPA / LTE         जीएसएम/एचएसपीए/एलटीई  ...
# 4     No cellular connectivity  कोई सेलुलर कनेक्टिविटी नहीं  ...
# ...                        ...                          ...  ...
# 9531                GSM / UMTS                               ...
# 9532                GSM / UMTS                               ...
# 9533                GSM / UMTS                               ...
# 9534                GSM / UMTS                               ...
# 9535                       GSM                               ...
#
#      banner_chipset_hl banner_chipset_hl_trans batsize batsize_trans bat_type  \
# 0      Rockchip RK3399     रोच्क्छिप् र्क्३३९९    4500          ४५००    Li-Po
# 1               MT8735                म्त्८७३५    3400          ३४००   Li-Ion
# 2               MT6753                म्त्६७५३    4080          ४०८०    Li-Po
# 3               MT6737                म्त्६७३७    2000          २०००   Li-Ion
# 4              MT8163A               म्त्८१६३अ    6100          ६१००   Li-Ion
# ...                ...                     ...     ...           ...      ...
# 9531                                               800           ८००   Li-Ion
# 9532                                              1000          १०००   Li-Ion
# 9533                                              1000          १०००   Li-Ion
# 9534                                              1000          १०००   Li-Ion
# 9535                                               690           ६९०   Li-Ion
#
#      bat_type_trans main_camera_single main_camera_single_trans  \
# 0             लि-पो               5 MP                   ५ म्प्
# 1           लि-इओन्          13 MP, AF             १३ म्प्, अफ़्
# 2             लि-पो          13 MP, AF             १३ म्प्, अफ़्
# 3           लि-इओन्           8 MP, AF              ८ म्प्, अफ़्
# 4           लि-इओन्               5 MP                   ५ म्प्
# ...             ...                ...                      ...
# 9531        लि-इओन्            3.15 MP                ३।१५ म्प्
# 9532        लि-इओन्               2 MP                   २ म्प्
# 9533        लि-इओन्               2 MP                   २ म्प्
# 9534        लि-इओन्               2 MP                   २ म्प्
# 9535        लि-इओन्
#
#      battery_stand_by battery_stand_by_trans
# 0
# 1
# 2
# 3
# 4
# ...               ...                    ...
# 9531
# 9532
# 9533
# 9534
# 9535      Up to 180 h
#
# [9536 rows x 88 columns]

# %%
def my_translate(val):
  #      if (val == ''):
  #          t1 = ''
  #  else:  
  #          a = anu.anuvaad(val)
  #          t1 = transliterate_numerals(a, lang_code='hi')
            
    e = model.translate(val, target_lang='hi')
    t1 = transliterate(e, sanscript.IAST, sanscript.DEVANAGARI)
    return t1

def my_transliterate(val):
    t2 = transliterate(val, sanscript.IAST, sanscript.DEVANAGARI)
    return t2

# %%
vect_translate = np.vectorize(my_translate)
vect_transliterate = np.vectorize(my_transliterate)

# %%
#for easynmt, use for loops for below code to deal with individual errors instead of np.vectorize, like:
#for i in range(len(phones)):
#    try:
#        phones['sound_loudspeaker_trans'][i] = my_translate(phones['sound_loudspeaker'][i])
#    except:
#        pass

# %%
try:
    phones['maker_name_trans'] = vect_transliterate(phones['maker_name'])
except:
    pass
try:
    phones['device_name_trans'] = vect_transliterate(phones['device_name'])
except:
    pass
try:
    phones['article_description_trans'] = vect_transliterate(phones['article_description'])
except:
    pass
try:
    phones['network_technology_trans'] = vect_translate(phones['network_technology'])
except:
    pass
try:
    phones['network_2g_bands_trans'] = vect_translate(phones['network_2g_bands'])
except:
    pass
try:
    phones['network_3g_bands_trans'] = vect_translate(phones['network_3g_bands'])
except:
    pass
try:
    phones['network_4g_bands_trans'] = vect_translate(phones['network_4g_bands'])
except:
    pass
try:
    phones['network_gprs_trans'] = vect_translate(phones['network_gprs'])
except:
    pass
try:
    phones['network_edge_trans'] = vect_translate(phones['network_edge'])
except:
    pass
try:
    phones['launch_announced_trans'] = vect_transliterate(phones['launch_announced'])
except:
    pass
try:
    phones['body_x_trans'] = vect_translate(phones['body_x'])
except:
    pass
try:
    phones['body_y_trans'] = vect_translate(phones['body_y'])
except:
    pass
try:
    phones['body_z_trans'] = vect_translate(phones['body_z'])
except:
    pass
try:
    phones['weight_trans'] = vect_translate(phones['weight'])
except:
    pass
try:
    phones['body_sim_trans'] = vect_translate(phones['body_sim'])
except:
    pass
try:
    phones['display_type_trans'] = vect_transliterate(phones['display_type'])
except:
    pass
try:
    phones['display_type_category_trans'] = vect_translate(phones['display_type_category'])
except:
    pass
try:
    phones['display_size_trans'] = vect_translate(phones['display_size'])
except:
    pass
try:
    phones['display_resolution_trans'] = vect_translate(phones['display_resolution'])
except:
    pass
try:
    phones['display_protection_trans'] = vect_translate(phones['display_protection'])
except:
    pass
try:
    phones['platform_chipset_trans'] = vect_transliterate(phones['platform_chipset'])
except:
    pass
try:
    phones['platform_cpu_trans'] = vect_translate(phones['platform_cpu'])
except:
    pass
try:
    phones['platform_gpu_trans'] = vect_transliterate(phones['platform_gpu'])
except:
    pass
try:
    phones['memory_card_slot_trans'] = vect_translate(phones['memory_card_slot'])
except:
    pass
try:
    phones['memory_internal_trans'] = vect_translate(phones['memory_internal'])
except:
    pass
try:
    phones['display_resolution_trans'] = vect_translate(phones['display_resolution'])
except:
    pass
try:
    phones['main_camera_features_trans'] = vect_transliterate(phones['main_camera_features'])
except:
    pass
try:
    phones['main_camera_video_trans'] = vect_transliterate(phones['main_camera_video'])
except:
    pass
try:
    phones['selfie_camera_single_trans'] = vect_transliterate(phones['selfie_camera_single'])
except:
    pass
try:
    phones['sound_loudspeaker_trans'] = vect_translate(phones['sound_loudspeaker'])
except:
    pass
try:
    phones['sound_3.5mm_jack_trans'] = vect_translate(phones['sound_3.5mm_jack'])
except:
    pass     
try:
    phones['comms_wlan_trans'] = vect_translate(phones['comms_wlan'])
except:
    pass 
try:
    phones['comms_bluetooth_trans'] = vect_translate(phones['comms_bluetooth'])
except:
    pass   
try:
    phones['comms_gps_trans'] = vect_translate(phones['comms_gps'])
except:
    pass
try:
    phones['comms_radio_trans'] = vect_translate(phones['comms_radio'])
except:
    pass
try:
    phones['comms_usb_trans'] = vect_translate(phones['comms_usb'])
except:
    pass    
try:
    phones['features_sensors_trans'] = vect_translate(phones['features_sensors'])
except:
    pass    
try:
    phones['colors_trans'] = vect_translate(phones['colors'])
except:
    pass    
try:
    phones['banner_released_hl_trans'] = vect_translate(phones['banner_released_hl'])
except:
    pass   
try:
    phones['banner_chipset_hl_trans'] = vect_transliterate(phones['banner_chipset_hl'])
except:
    pass    
try:
    phones['batsize_trans'] = vect_transliterate(phones['batsize'])
except:
    pass    
try:
    phones['bat_type_trans'] = vect_transliterate(phones['bat_type'])
except:
    pass    
try:
    phones['main_camera_single_trans'] = vect_transliterate(phones['main_camera_single'])
except:
    pass   
try:
    phones['battery_stand_by_trans'] = vect_translate(phones['battery_stand_by'])
except:
    pass

# %%
#phones1 = phones[0:20]
#phones.to_csv(r'./5.trans_full_output.csv', index = False)
phones.to_csv('5.trans_full_output.csv', index = False)
