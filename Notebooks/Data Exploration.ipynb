# %%
import pandas as pd
import numpy as np
import sweetviz as sv
from googletrans import Translator

# %%
phones = pd.read_csv('GSM (copy).csv')
phones
# Out:
#      maker_name           device_name  \
# 0          Acer     Chromebook Tab 10
# 1          Acer         Iconia Talk S
# 2          Acer        Liquid Z6 Plus
# 3          Acer             Liquid Z6
# 4          Acer  Iconia Tab 10 A3-A40
# ...         ...                   ...
# 9531        ZTE                  F600
# 9532        ZTE                  F103
# 9533        ZTE                  F101
# 9534        ZTE                  F100
# 9535        ZTE       Coral200 Sollar
#
#                                     article_description  \
# 0     Acer Chromebook Tab 10 tablet. Announced Mar 2...
# 1     Acer Iconia Talk S Android tablet. Announced A...
# 2     Acer Liquid Z6 Plus Android smartphone. Announ...
# 3     Acer Liquid Z6 Android smartphone. Announced A...
# 4     Acer Iconia Tab 10 A3-A40 Android tablet. Anno...
# ...                                                 ...
# 9531  ZTE F600 phone. Announced  2009. Features 2.4″...
# ...

# %%
Report = sv.analyze(phones)
Report.show_html()
# Out:
#                                              |                                                                …
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
phones.columns.values
# Out:
# array(['maker_name', 'device_name', 'article_description',
#        'device_img_link', 'reference_link', 'network_technology',
#        'network_2g_bands', 'network_3g_bands', 'network_4g_bands',
#        'network_gprs', 'network_edge', 'launch_announced', 'body_x',
#        'body_y', 'body_z', 'weight', 'body_sim', 'display_type',
#        'display_type_category', 'display_size', 'display_resolution',
#        'display_protection', 'platform_chipset', 'platform_cpu',
#        'platform_gpu', 'memory_card_slot', 'memory_internal',
#        'main_camera_features', 'main_camera_video',
#        'selfie_camera_single', 'sound_loudspeaker', 'sound_3.5mm_jack',
#        'comms_wlan', 'comms_bluetooth', 'comms_gps', 'comms_radio',
#        'comms_usb', 'features_sensors', 'colors', 'price',
#        'banner_released_hl', 'banner_chipset_hl', 'batsize',
#        'banner_battype_hl', 'main_camera_single', 'battery_stand_by'],
#       dtype=object)
